# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as anim
from tqdm import tqdm

# %%
def Funcion(x,omega):
    return -omega**2*x

# %%
def MetodoVerlet(a,x0,v0,t,omega,h):   
    #siguiendo el codigo de clase
    x=np.zeros_like(t)
    v=np.zeros_like(t)
    x[0]=x0
    x[1]=x[0]+h*v0
    v[0]=v0
    v[1]=x[0]+h*a(x[1],omega)
    for i in range(2,len(x)):
        x[i]= 2*x[i-1]-x[i-2]+ a(x[i-1],omega)*h**2
        v[i] = (x[i]-x[i-2])/(2*h)
    return x,v

# %%
omega=np.pi
h=0.1 
t=np.arange(0,20,h)
x0=1
v0=1

# %%
x_esta,vx_esta= MetodoVerlet(Funcion,x0,v0,t,omega,h)

# %%
scale=1
t1= t[::scale]
X_=x_esta[::scale]
VX=vx_esta[::scale]

fig = plt.figure(figsize=(8,5))
ax = fig.add_subplot(121)
ax1 = fig.add_subplot(122)
#se inicializa el gráfico
def init():
    ax.clear()
    ax.set_xlim(-2,2)
    ax.set_ylim(-2,2)
    ax1.clear()
    ax1.set_ylim(-2,2)
#se actualiza el gráfico       
def Update(i):   
    init()
    x = X_[i]
    vx =VX[i]
    circle = plt.Circle( (0,x), 0.8, fill=False )
    ax.add_patch(circle)   
    ax.arrow(0,x,0,vx,head_width=0.1,length_includes_head=True)
    ax1.plot( t1[0:i] , X_[0:i]) 
Animation = anim.FuncAnimation(fig,Update,frames=len(t1),init_func=init)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Como podemos ver esta zona es la región estable por lo tanto se ve un oscilador armonico

# %%
omega=np.pi
h_2=(2+0.0001)/(omega) 
t_2=np.arange(0,20,h_in)
x0=1
v0=1

# %%
x_2,vx_2= MetodoVerlet(Funcion,x0,v0,t_2,omega,h_2)

# %%
##  METODO PARA GRAFICAR TENIENDO EN CUENTA X_2 Y V_2
scale_in=1
t1_in= t_in[::scale_in]
X_2=x_2[::scale_in]
VX_2=vx_2[::scale_in]
fig2 = plt.figure(figsize=(8,5))
ax2 = fig2.add_subplot(121)
ax3 = fig2.add_subplot(122)
def init_in():
    ax2.clear()
    ax2.set_xlim(-2,2)
    ax3.clear()
def Update_in(i):
    init_in()
    x = X_2[i]
    vx =VX_2[i]
    circle = plt.Circle( (0,x), 0.3, fill=False )
    ax2.add_patch(circle)      
    ax2.arrow(0,x,0,vx,head_width=0.1,length_includes_head=True)   
    ax3.plot(t1_in[0:i],X_in[0:i])    
Animation_in= anim.FuncAnimation(fig2,Update_in,frames=len(t1_in),init_func=init)
# Out:
# <img src="data:image/png;base64,..." width="800">
